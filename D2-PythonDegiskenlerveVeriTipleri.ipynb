# %%
print("Merhaba, İGÜ - İSTKA / Ders 3") # print ekrana çıktı veren bir koddur.
# Out:
# Merhaba, İGÜ - İSTKA / Ders 3

# %%
import sys
print(sys.version)

#Google Colab'a Google Drive Bağlantısı
from google.colab import drive
drive.mount('/content/drive')

#Google Drive'daki Dosyaya Erişim Bağlantısı
import os
os.chdir('/content/drive/My Drive/veri_yapilari_istka')
# !pwd
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/veri_yapilari_istka

# %%
# Geçerli değişken tanımlaması

degisken_1 = 10
degisken_2 = 20
degisken_3 = 30

# %%
# Geçersiz değişken tanımlaması
"""
1degisken = 40
degisken-4 = 50
"""
# Out:
# '\n1degisken = 40\ndegisken-4 = 50\n'

# %%
# Değişken Tanımlama İşlemi
x = 5
y = "Merhaba Dünya"

print(x)
print(y)
# Out:
# 5
# Merhaba Dünya

# %%
# Integer - Tamsayı tanımlaması

a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
#Float - Ondalıklı sayı tanımlaması

b = 20.5
print(type(b))
# Out:
# <class 'float'>

# %%
# integer - float dönüşümü gerçekleştirilmesi

x = 10
y = float(x)
print(y,type(y))
# Out:
# 10.0 <class 'float'>

# %%
# float - integer dönüşümü gerçekleştirilmesi

a = 12.34
b = int(a)
print(b,type(b))
# Out:
# 12 <class 'int'>

# %%
# String metinsel içerik tanımlaması

c = 'Python Programlama'
print(c)
print(type(c))
# Out:
# Python Programlama
# <class 'str'>

# %%
# Boolean tanımlama

d = True
e = False
print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
my_list = [1,2,3,4,5]
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
# tuple tanımalması

my_tuple = (1,2,3,4,5)
print(my_tuple)
print(type(my_tuple))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
#dictionary örneği

notlar =  {
    "Ali" : 85,
    "Veli" : 90,
    "Ayşe" : 78
 }

notlar["Fatma"] = 92 # Yeni öğrenci ekleme

notlar["Ali"] = 88 # Bir öğrencinin notunu güncelleme

print(notlar)
# Out:
# {'Ali': 88, 'Veli': 90, 'Ayşe': 78, 'Fatma': 92}

# %%
print(notlar.keys())
print(notlar.values())
print(notlar.items())
# Out:
# dict_keys(['Ali', 'Veli', 'Ayşe', 'Fatma'])
# dict_values([88, 90, 78, 92])
# dict_items([('Ali', 88), ('Veli', 90), ('Ayşe', 78), ('Fatma', 92)])

# %%
# Set - Küme örneği -> Bir yazılım etkinliğine katılan kişilerin oluşturduğu kümeler

kodyazanlar = { "Ahmet", "Mehmet", "Ayşe"}
kodyazmayanlar = {"Ayşe", "Fatma", "Veli"}

# Kafasına Göre Takılan Öğrenciler

ortak = kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına göre takılanlar: ", ortak)

# Etkinlikte Kod Yazmayan Öğrencilerin Tespiti

kod_yazmayan = kodyazmayanlar.difference(kodyazanlar)
print("Kod çalışması yapmayan öğrenci listesi: ", kod_yazmayan)

# Yazılım Eğitiminin Öğrenci İmza Listesi

imza_listesi = kodyazanlar.union(kodyazmayanlar)
print("Etkinlik katılımcı listesi: ", imza_listesi)
# Out:
# Kafasına göre takılanlar:  {'Ayşe'}
# Kod çalışması yapmayan öğrenci listesi:  {'Veli', 'Fatma'}
# Etkinlik katılımcı listesi:  {'Veli', 'Mehmet', 'Fatma', 'Ahmet', 'Ayşe'}

# %%
giris = input("Bir sayi gir: ")
try :
  num=(float(giris))
  print(f"Girilen sayı: {num}, tipi: {type(num)},",abs(num))
except ValueError:
  print("Geçersiz veri girdiniz.")
# Out:
# Bir sayi gir: -12
# Girilen sayı: -12.0, tipi: <class 'float'>, 12.0
